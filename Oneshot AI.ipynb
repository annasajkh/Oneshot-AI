# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
# !pip install -q pyunpack
# !pip install -q patool

import os.path
from os import path
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
import tensorflow as tf
import time
from pyunpack import Archive


if not path.exists("checkpoint"):
  # !gdown --id 1-7OIaIJ_YbuEHUrZzMl32DOZeOr-Ir2u
  Archive("checkpoint_run1.tar").extractall(".")

if not path.exists("models"):
  gpt2.download_gpt2(model_name="355M")

tf.reset_default_graph()
session = gpt2.start_tf_sess()
gpt2.load_gpt2(session, run_name='run1')

print("generating this may take a while....")
gpt2.generate(session,
              model_name="355M",
              length=1024, #tokens
              prefix="hello niko.", 
              temperature=0.7,
              nsamples=1,
              batch_size=1,
)
# Out:
# TensorFlow 1.x selected.
#   Building wheel for gpt-2-simple (setup.py) ... done
#      |████████████████████████████████| 81kB 4.1MB/s
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Downloading...
# From: https://drive.google.com/uc?id=1-7OIaIJ_YbuEHUrZzMl32DOZeOr-Ir2u
# To: /content/checkpoint_run1.tar
# 1.43GB [00:11, 126MB/s]
# Fetching checkpoint: 1.05Mit [00:00, 275Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 6.84Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 427Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [03:26, 6.87Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 191Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 7.64Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 9.64Mit/s]
# Loading checkpoint checkpoint/run1/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-1000
# generating this may take a while....
# hello niko.
#
# niko:
# Thank you for playing.
#
# niko:
# It's a... small bed.
#
# niko:
# I guess players are supposed to sleep on the floor?
#
# niko:
# The blanket has quite a few patches.
#
# niko:
# A bulletin board with lots of papers on it.
#
# niko:
# A bulletin board with lots of papers on it.
#
# unknown:
# I don't know what this is.
#
# unknown:
# I heard someone say something about radios.
#
# unknown:
# I wonder what that word means...
#
# niko:
# Oh! It's an emergency!
#
# unknown:
# I can hear that!
#
# unknown:
# The messiah is looking for you!
#
# unknown:
# Tell him I like his book!
#
# niko:
# I will!
#
# unknown:
# Tell him I like his book!
#
# niko:
# He'll make a nice bookmark!
#
# unknown:
# You've been studying hard all week!
#
# unknown:
# The library on the surface doubles as a refuge for situations like this!
#
# unknown:
# The closest library to the city is on the surface, but...
#
# unknown:
# ...we prefer to stay here for now.
#
# niko:
# Uh... thanks!
#
# unknown:
# We have a guest room in the attic down the hall!
#
# unknown:
# Would you like to visit?
#
# niko:
# Yeah! We have a guest room in the attic down the hall!
#
# unknown:
# Oh! Would you like to stay?
#
# niko:
# I... guess I do!
#
# unknown:
# Well, why not?
#
# unknown:
# The land is fragmenting at an alarming rate...
#
# niko:
# The village is barely holding on...
#
# unknown:
# Looks like the Glen is fading faster than ever, now...
#
# unknown:
# The land is fragmenting at an alarming rate...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# niko:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
#
# unknown:
# The village is barely holding on...
